# %%
import numpy as np
import random

class AntColony:
    def __init__(self, distance_matrix, num_ants, num_iterations, alpha, beta, evaporation_rate):
        self.distance_matrix = distance_matrix
        self.num_ants = num_ants
        self.num_iterations = num_iterations
        self.alpha = alpha
        self.beta = beta
        self.evaporation_rate = evaporation_rate
        self.num_cities = distance_matrix.shape[0]
        self.pheromone_matrix = np.ones((self.num_cities, self.num_cities))

    def _calculate_probabilities(self, ant, visited):
        pheromone = self.pheromone_matrix[ant, :]
        visibility = 1 / self.distance_matrix[ant, :]
        probabilities = (pheromone ** self.alpha) * (visibility ** self.beta)
        # Convert visited set to array for indexing
        visited = np.array(list(visited))
        probabilities[visited] = 0
        return probabilities / np.sum(probabilities)

    def _update_pheromones(self, all_paths):
        self.pheromone_matrix *= (1 - self.evaporation_rate)
        for path, length in all_paths:
            for i in range(len(path) - 1):
                self.pheromone_matrix[path[i], path[i + 1]] += 1 / length

    def solve(self):
        best_path = None
        best_length = float('inf')

        for iteration in range(self.num_iterations):
            all_paths = []
            for ant in range(self.num_ants):
                path = [random.randint(0, self.num_cities - 1)]
                visited = set(path)

                for _ in range(self.num_cities - 1):
                    current_city = path[-1]
                    probabilities = self._calculate_probabilities(current_city, visited)
                    next_city = np.random.choice(range(self.num_cities), p=probabilities)
                    path.append(next_city)
                    visited.add(next_city)

                # Return to starting city
                path.append(path[0])
                length = self._calculate_path_length(path)
                all_paths.append((path, length))

                if length < best_length:
                    best_length = length
                    best_path = path

            self._update_pheromones(all_paths)
            print(f"Iteration {iteration + 1}, Best Length: {best_length}")

        return best_path, best_length

    def _calculate_path_length(self, path):
        return sum(self.distance_matrix[path[i], path[i + 1]] for i in range(len(path) - 1))

# Example usage
if __name__ == "__main__":
    # Create a distance matrix for 5 cities
    distance_matrix = np.array([[0, 2, 9, 10, 3],
                                 [1, 0, 6, 4, 5],
                                 [15, 7, 0, 8, 9],
                                 [6, 3, 12, 0, 4],
                                 [10, 4, 8, 2, 0]])

    aco = AntColony(distance_matrix, num_ants=10, num_iterations=100, alpha=1.0, beta=2.0, evaporation_rate=0.5)
    best_path, best_length = aco.solve()
    print("Best Path:", best_path)
    print("Best Length:", best_length)
# Out:
# <ipython-input-2-a801df5fe8c0>:17: RuntimeWarning: divide by zero encountered in divide
#   visibility = 1 / self.distance_matrix[ant, :]
# Iteration 1, Best Length: 24
# Iteration 2, Best Length: 24
# Iteration 3, Best Length: 23
# Iteration 4, Best Length: 23
# Iteration 5, Best Length: 23
# Iteration 6, Best Length: 23
# Iteration 7, Best Length: 23
# Iteration 8, Best Length: 23
# Iteration 9, Best Length: 23
# Iteration 10, Best Length: 23
# Iteration 11, Best Length: 23
# Iteration 12, Best Length: 23
# Iteration 13, Best Length: 23
# Iteration 14, Best Length: 23
# Iteration 15, Best Length: 23
# Iteration 16, Best Length: 23
# Iteration 17, Best Length: 23
# Iteration 18, Best Length: 23
# Iteration 19, Best Length: 23
# Iteration 20, Best Length: 23
# Iteration 21, Best Length: 23
# Iteration 22, Best Length: 23
# Iteration 23, Best Length: 23
# Iteration 24, Best Length: 23
# Iteration 25, Best Length: 23
# Iteration 26, Best Length: 23
# Iteration 27, Best Length: 23
# Iteration 28, Best Length: 23
# Iteration 29, Best Length: 23
# Iteration 30, Best Length: 23
# Iteration 31, Best Length: 23
# Iteration 32, Best Length: 23
# Iteration 33, Best Length: 23
# Iteration 34, Best Length: 23
# Iteration 35, Best Length: 23
# Iteration 36, Best Length: 23
# Iteration 37, Best Length: 23
# Iteration 38, Best Length: 23
# Iteration 39, Best Length: 23
# Iteration 40, Best Length: 23
# Iteration 41, Best Length: 23
# Iteration 42, Best Length: 23
# Iteration 43, Best Length: 23
# Iteration 44, Best Length: 23
# Iteration 45, Best Length: 23
# Iteration 46, Best Length: 23
# Iteration 47, Best Length: 23
# Iteration 48, Best Length: 23
# Iteration 49, Best Length: 23
# Iteration 50, Best Length: 23
# Iteration 51, Best Length: 23
# Iteration 52, Best Length: 23
# Iteration 53, Best Length: 23
# Iteration 54, Best Length: 23
# Iteration 55, Best Length: 23
# Iteration 56, Best Length: 23
# Iteration 57, Best Length: 23
# Iteration 58, Best Length: 23
# Iteration 59, Best Length: 23
# Iteration 60, Best Length: 23
# Iteration 61, Best Length: 23
# Iteration 62, Best Length: 23
# Iteration 63, Best Length: 23
# Iteration 64, Best Length: 23
# Iteration 65, Best Length: 23
# Iteration 66, Best Length: 23
# Iteration 67, Best Length: 23
# Iteration 68, Best Length: 23
# Iteration 69, Best Length: 23
# Iteration 70, Best Length: 23
# Iteration 71, Best Length: 23
# Iteration 72, Best Length: 23
# Iteration 73, Best Length: 23
# Iteration 74, Best Length: 23
# Iteration 75, Best Length: 23
# Iteration 76, Best Length: 23
# Iteration 77, Best Length: 23
# Iteration 78, Best Length: 23
# Iteration 79, Best Length: 23
# Iteration 80, Best Length: 23
# Iteration 81, Best Length: 23
# Iteration 82, Best Length: 23
# Iteration 83, Best Length: 23
# Iteration 84, Best Length: 23
# Iteration 85, Best Length: 23
# Iteration 86, Best Length: 23
# Iteration 87, Best Length: 23
# Iteration 88, Best Length: 23
# Iteration 89, Best Length: 23
# Iteration 90, Best Length: 23
# Iteration 91, Best Length: 23
# Iteration 92, Best Length: 23
# Iteration 93, Best Length: 23
# Iteration 94, Best Length: 23
# Iteration 95, Best Length: 23
# Iteration 96, Best Length: 23
# Iteration 97, Best Length: 23
# Iteration 98, Best Length: 23
# Iteration 99, Best Length: 23
# Iteration 100, Best Length: 23
# Best Path: [3, 1, 0, 4, 2, 3]
# Best Length: 23
